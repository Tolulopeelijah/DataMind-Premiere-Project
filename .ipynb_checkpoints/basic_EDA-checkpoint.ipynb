# %%
#pip install dateparser

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dateparser
import numpy as np

# Sklearn tools
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import  f_regression, SelectKBest
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import FunctionTransformer, MaxAbsScaler
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Personally defined module
import Useful_tools as ut

pd.set_option("display.max_columns", None)

# %%
#Changes the event date to a datetime datatype
#df1 = pd.read_csv('Africa_1997-2020_Jan08.csv', encoding = 'latin1', 
                 #parse_dates=['EVENT_DATE'], date_parser=dateparser.parse)

#No changes
df = pd.read_csv('Africa_1997-2020_Jan08.csv', encoding = 'latin1')

# %%
df.head()
# Out:
#    ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY       EVENT_DATE  YEAR  TIME_PRECISION  \
# 0   12          ALG1                 1  01-janvier-1997  1997               1
# 1   12          ALG2                 2  02-janvier-1997  1997               1
# 2   12          ALG3                 3  03-janvier-1997  1997               1
# 3   12          ALG4                 4  04-janvier-1997  1997               1
# 4   12          ALG5                 5  05-janvier-1997  1997               1
#
#                    EVENT_TYPE SUB_EVENT_TYPE                    ACTOR1  \
# 0  Violence against civilians         Attack  GIA: Armed Islamic Group
# 1  Violence against civilians         Attack  GIA: Armed Islamic Group
# 2  Violence against civilians         Attack  GIA: Armed Islamic Group
# 3  Violence against civilians         Attack  GIA: Armed Islamic Group
# 4  Violence against civilians         Attack  GIA: Armed Islamic Group
#
#   ASSOC_ACTOR_1  INTER1               ACTOR2 ASSOC_ACTOR_2  INTER2  \
# 0           NaN       2  Civilians (Algeria)           NaN       7
# 1           NaN       2  Civilians (Algeria)           NaN       7
# 2           NaN       2  Civilians (Algeria)           NaN       7
# 3           NaN       2  Civilians (Algeria)           NaN       7
# 4           NaN       2  Civilians (Algeria)           NaN       7
#
#    INTERACTION           REGION  COUNTRY    ADMIN1    ADMIN2 ADMIN3  \
# 0           27  Northern Africa  Algeria    Tipaza  Douaouda    NaN
# 1           27  Northern Africa  Algeria  Relizane   Mazouna    NaN
# 2           27  Northern Africa  Algeria     Saida      Youb    NaN
# 3           27  Northern Africa  Algeria     Blida     Blida    NaN
# 4           27  Northern Africa  Algeria    Tipaza  Douaouda    NaN
#
#         LOCATION  LATITUDE  LONGITUDE  GEO_PRECISION         SOURCE  \
# 0       Douaouda     36672       2789              1  Algeria Watch
# 1       Hassasna     36133        883              1  Algeria Watch
# 2  Hassi El Abed     34966        -29              1  Algeria Watch
# 3          Blida     36469       2829              1  Algeria Watch
# 4       Douaouda     36672       2789              1  Algeria Watch
#
#   SOURCE_SCALE                                              NOTES  FATALITIES  \
# 0        Other  5 January: Beheading of 5 citizens in Douaouda...           5
# 1        Other            Two citizens were beheaded in Hassasna.           2
# 2        Other  Two citizens were killed in a raid on the vill...           2
# 3        Other  4 January: 16 citizens were murdered in the vi...          16
# 4        Other  5 January: Killing of 18 citizens in the Olivi...          18
#
#     TIMESTAMP
# 0  1582579226
# 1  1582579226
# 2  1582579226
# 3  1582579226
# 4  1582579226

# %%
#df.head(2).T

# %%
df.shape
# Out:
# (65535, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ISO               65535 non-null  int64
#  1   EVENT_ID_CNTY     65535 non-null  object
#  2   EVENT_ID_NO_CNTY  65535 non-null  int64
#  3   EVENT_DATE        65535 non-null  object
#  4   YEAR              65535 non-null  int64
#  5   TIME_PRECISION    65535 non-null  int64
#  6   EVENT_TYPE        65535 non-null  object
#  7   SUB_EVENT_TYPE    65535 non-null  object
#  8   ACTOR1            65535 non-null  object
#  9   ASSOC_ACTOR_1     12768 non-null  object
#  10  INTER1            65535 non-null  int64
#  11  ACTOR2            50346 non-null  object
#  12  ASSOC_ACTOR_2     11167 non-null  object
#  13  INTER2            65535 non-null  int64
#  14  INTERACTION       65535 non-null  int64
#  15  REGION            65535 non-null  object
#  16  COUNTRY           65535 non-null  object
#  17  ADMIN1            65535 non-null  object
#  18  ADMIN2            65535 non-null  object
#  19  ADMIN3            52331 non-null  object
#  20  LOCATION          65535 non-null  object
#  21  LATITUDE          65535 non-null  int64
#  22  LONGITUDE         65535 non-null  int64
#  23  GEO_PRECISION     65535 non-null  int64
#  24  SOURCE            65535 non-null  object
#  25  SOURCE_SCALE      65535 non-null  object
#  26  NOTES             62931 non-null  object
#  27  FATALITIES        65535 non-null  int64
#  28  TIMESTAMP         65535 non-null  int64
# dtypes: int64(12), object(17)
# memory usage: 14.5+ MB

# %%
cat = []
num = []
for i in df.columns:
    if df[i].dtype == 'O':
        cat.append(i)
    else: num.append(i)
print(cat)
# Out:
# ['EVENT_ID_CNTY', 'EVENT_DATE', 'EVENT_TYPE', 'SUB_EVENT_TYPE', 'ACTOR1', 'ASSOC_ACTOR_1', 'ACTOR2', 'ASSOC_ACTOR_2', 'REGION', 'COUNTRY', 'ADMIN1', 'ADMIN2', 'ADMIN3', 'LOCATION', 'SOURCE', 'SOURCE_SCALE', 'NOTES']

# %%
df[cat].nunique().sort_values()
# Out:
# REGION                5
# EVENT_TYPE            6
# COUNTRY              20
# SOURCE_SCALE         23
# SUB_EVENT_TYPE       25
# ADMIN1              317
# ACTOR2             1402
# ACTOR1             1645
# ADMIN2             1832
# ASSOC_ACTOR_1      1866
# ASSOC_ACTOR_2      2069
# ADMIN3             2672
# SOURCE             4129
# EVENT_DATE         8244
# LOCATION           8381
# NOTES             55547
# EVENT_ID_CNTY     65535
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0] * 100)[df.isnull().sum() > 0 ] #percentage of missing values
# Out:
# ASSOC_ACTOR_1    80.517281
# ACTOR2           23.176928
# ASSOC_ACTOR_2    82.960250
# ADMIN3           20.148013
# NOTES             3.973449
# dtype: float64

# %%
list(df['NOTES'].iloc[:5].values)
# Out:
# ['5 January: Beheading of 5 citizens in Douaouda (Tipaza).',
#  'Two citizens were beheaded in Hassasna.',
#  'Two citizens were killed in a raid on the village of Hassi El Abd. Several televisions were destroyed and the school of the village burned.',
#  '4 January: 16 citizens were murdered in the village of Benachour (Blida) by masked men a few hundred meters away from a military camp. It is of note that the citizens of this village had refused to set up armed militias.',
#  '5 January: Killing of 18 citizens in the Oliviers district of Douaouda (Tipaza). Among the victims are 3 children and 6 women. This region had refused to organise armed militias.']

# %%
 dr_df = df.drop(columns = ['EVENT_ID_CNTY', 'ASSOC_ACTOR_1', 'ASSOC_ACTOR_2'])

# %%
dr_df['REGION'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
dr_df[['REGION']].groupby('REGION')['REGION'].count()
# Out:
# REGION
# Eastern Africa     15592
# Middle Africa      33945
# Northern Africa     9936
# Southern Africa       77
# Western Africa      5985
# Name: REGION, dtype: int64

# %%
dr_df['EVENT_TYPE'].value_counts().plot(kind = 'bar')
plt.show()
dr_df['COUNTRY'].value_counts().plot(kind = 'bar')
plt.show()
dr_df['SOURCE_SCALE'].value_counts().plot(kind = 'bar')
plt.show()
dr_df['SUB_EVENT_TYPE'].value_counts().plot(kind = 'bar')
plt.show()

# %%
dr_df['SUB_EVENT_TYPE'].value_counts().plot(kind = 'hist')
plt.show()

# %% [markdown]
# # Contributions from Rabiat
#
#
# ### 1. Added `pd.set_option("display.max_columns", None)` to display all the columns of the dataset
# ### 2. Created 2 plots

# %%
df.tail()
# Out:
#        ISO EVENT_ID_CNTY  EVENT_ID_NO_CNTY        EVENT_DATE  YEAR  \
# 65530  404        KEN318               318   25-octobre-1998  1998
# 65531  404        KEN319               319  02-novembre-1998  1998
# 65532  404        KEN320               320  10-novembre-1998  1998
# 65533  404        KEN323               323  14-novembre-1998  1998
# 65534  404        KEN322               322  14-novembre-1998  1998
#
#        TIME_PRECISION                  EVENT_TYPE    SUB_EVENT_TYPE  \
# 65530               1  Violence against civilians            Attack
# 65531               1                    Protests  Peaceful protest
# 65532               1                     Battles       Armed clash
# 65533               1                     Battles       Armed clash
# 65534               1                     Battles       Armed clash
#
#                                                 ACTOR1  \
# 65530                      OLF: Oromo Liberation Front
# 65531                               Protesters (Kenya)
# 65532  SPLM/A: Sudan People's Liberation Movement/Army
# 65533  SPLM/A: Sudan People's Liberation Movement/Army
# 65534  SPLM/A: Sudan People's Liberation Movement/Army
#
#                        ASSOC_ACTOR_1  INTER1  \
# 65530  Borana Ethnic Militia (Kenya)       2
# 65531               Students (Kenya)       6
# 65532                            NaN       2
# 65533                            NaN       2
# 65534                            NaN       2
#
#                                                   ACTOR2  \
# 65530                                  Civilians (Kenya)
# 65531                                                NaN
# 65532  SPLM/A-Kerubino: Sudan People's Liberation Mov...
# 65533  SPLM/A-Kerubino: Sudan People's Liberation Mov...
# 65534  SPLM/A-Kerubino: Sudan People's Liberation Mov...
#
#                       ASSOC_ACTOR_2  INTER2  INTERACTION          REGION  \
# 65530  Degodia Ethnic Group (Kenya)       7           27  Eastern Africa
# 65531                           NaN       0           60  Eastern Africa
# 65532                           NaN       2           22  Eastern Africa
# 65533                           NaN       2           22  Eastern Africa
# 65534                           NaN       2           22  Eastern Africa
#
#       COUNTRY   ADMIN1      ADMIN2           ADMIN3 LOCATION  LATITUDE  \
# 65530   Kenya    Wajir  Wajir East         Township     Tuli      1643
# 65531   Kenya  Nairobi     Starehe  Nairobi Central  Nairobi     -1283
# 65532   Kenya  Nairobi     Starehe  Nairobi Central  Nairobi     -1283
# 65533   Kenya  Nairobi     Starehe  Nairobi Central  Nairobi     -1283
# 65534   Kenya  Nairobi     Starehe  Nairobi Central  Nairobi     -1283
#
#        LONGITUDE  GEO_PRECISION      SOURCE SOURCE_SCALE  \
# 65530      40343              1  All Africa     Regional
# 65531      36817              1  All Africa     Regional
# 65532      36817              1  All Africa     Regional
# 65533      36817              1  All Africa     Regional
# 65534      36817              1  All Africa     Regional
#
#                                                    NOTES  FATALITIES  \
# 65530  OLF and Borana ethnic militia attack civilians...          28
# 65531  University students protest over killing in Wa...           0
# 65532  Garangs SPLA security men raid home of Kerubin...           0
# 65533       Rival SPLA factions battle at police station           0
# 65534  Gang of youth loyal to Kerubinos SPLA faction ...           0
#
#         TIMESTAMP
# 65530  1553544833
# 65531  1567465412
# 65532  1604344065
# 65533  1583194169
# 65534  1583194169

# %%
plt.figure(figsize=(4,3))
colors=sns.color_palette()[3]
ax = sns.barplot(y='EVENT_TYPE', x='FATALITIES',  data=df, color=colors)
plt.title('Plot of event type versus fatality')
plt.xlabel('Fatality $')
plt.ylabel('Event type')
#ax.bar_label(ax.containers[0])
#ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

plt.show()

# %%
plt.figure(figsize=(7,5))
colors=sns.color_palette()[4]
ax = sns.barplot(x='SUB_EVENT_TYPE', y='FATALITIES',  data=df, color=colors)
plt.title('Plot of event sub-type versus fatality')
plt.ylabel('Fatality')
plt.xlabel('Event sub-type')
#ax.bar_label(ax.containers[0])
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

plt.show()

# %% [markdown]
# # Building machine learning Model: To predict number of fatalities

# %% [markdown]
# ## Model without the text columns

# %% [markdown]
# ***Here we ectract just the numerical columns which we believe contributes to predicting fatalities and covert them into a list

# %%
#Numeric columns
num_list= ["YEAR", "INTER1", "INTER2", 
           "INTERACTION", "LATITUDE", "LONGITUDE", "GEO_PRECISION" ]

#Convert to List
numeric_data_only = dr_df[num_list]

# %%
# split the dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(dr_df[num_list],df["FATALITIES"],test_size=0.3,random_state=42)

# %%
# Instantiate Linear Regression model
model = LinearRegression()

# %%
#Fit the model
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Perform prediction with it
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation
#
# ***For the evaluation metric, we considered the mean absolute error, the root mean squared error and the r2-score.

# %%
# mean absolute error
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 11.17353491719403

# %%
# Root mean squared error
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# 51.791728104622685

# %%
# R2- score
r2= r2_score(y_test, y_pred)
r2
# Out:
# 0.02482171489958307

# %% [markdown]
# ## Model with text columns included in the prediction
#
# ***Here we incoporate the text columns into our prediction using natural language processing tools such as:
#
#         *** HashingVectorizer
#         *** N-gram of words
#
# ***The numeric and text columns were incoperated using the Function transformer and the feature union tool.
#
# ***We next built a machine learning pipeline where we defined the follwoing:
#
#     *** SelectKBest: A dimension reduction technique using `f_regression` as the statistical metric and we considered the 10 best features.
#     *** SparseInteractions: A class which defines polynomial interaction method. We have specified polynomial degree of 2.
#     *** MaxAbsScale: We used this tool to scale the features such that the value ranges between 0 and 1.

# %%
NUMERIC_COLUMNS= ["ISO","EVENT_ID_NO_CNTY","YEAR","TIME_PRECISION", "INTER1", "INTER2", 
           "INTERACTION", "LATITUDE", "LONGITUDE", "GEO_PRECISION", "TIMESTAMP" ]
LABELS=["FATALITIES"]

# %%
def combine_text_columns(data_frame, to_drop = NUMERIC_COLUMNS + LABELS):
    """ converts all text in each row of data_frame to single vector """
    
    # Drop non-text columns that are in the df
    to_drop = set(to_drop) & set(data_frame.columns.tolist())
    text_data = data_frame.drop(to_drop, axis=1)
    
    # Replace nans with blanks
    text_data.fillna("", inplace=True)
    
    # Join all text items in a row that have a space in between
    return text_data.apply(lambda x: " ".join(x), axis=1)

# %%
get_text_data = FunctionTransformer(combine_text_columns, validate=False)
get_numeric_data = FunctionTransformer(lambda x: x[NUMERIC_COLUMNS], validate=False)

# %%
# Select K best features
K = 10
TOKENS_ALPHANUMERIC = '[A-Za-z0-9]+(?=\\s+)'

# %%
# Instantiate pipeline
pipeline = Pipeline([
        ('union', FeatureUnion(
            transformer_list = [
                ('numeric_features', Pipeline([
                    ('selector', get_numeric_data)
                   
                ])),
                ('text_features', Pipeline([
                    ('selector', get_text_data),
                    ('vectorizer', HashingVectorizer(token_pattern=TOKENS_ALPHANUMERIC,
                                                       norm=None,binary=False,
                                                     ngram_range=(1,2))),
                    ('dim_red', SelectKBest(score_func=f_regression, k=K))
                ]))
             ]
        )),
        ('int', ut.SparseInteractions(degree=2)),
        ('scale', MaxAbsScaler()),
        ('clf', LinearRegression())
    ])

# %%
# Drop the target column
X = dr_df.drop(columns=["FATALITIES"])
# Extract only the target column
y = dr_df["FATALITIES"]

X_tr, X_te, y_tr, y_te = train_test_split(X,y, random_state=42)

# %%
# Here we fit our pipeline
pipeline.fit(X_tr, y_tr)
# Out:
# Pipeline(steps=[('union',
#                  FeatureUnion(transformer_list=[('numeric_features',
#                                                  Pipeline(steps=[('selector',
#                                                                   FunctionTransformer(func=<function <lambda> at 0x7f9d110ed990>))])),
#                                                 ('text_features',
#                                                  Pipeline(steps=[('selector',
#                                                                   FunctionTransformer(func=<function combine_text_columns at 0x7f9d118bc700>)),
#                                                                  ('vectorizer',
#                                                                   HashingVectorizer(ngram_range=(1,
#                                                                                                  2),
#                                                                                     norm=None,
#                                                                                     token_pattern='[A-Za-z0-9]+(?=\\s+)')),
#                                                                  ('dim_red',
#                                                                   SelectKBest(score_func=<function f_regression at 0x7f9d606045e0>))]))])),
#                 ('int', SparseInteractions()), ('scale', MaxAbsScaler()),
#                 ('clf', LinearRegression())])

# %%
# We make predictions with our pipeline 
pred = pipeline.predict(X_te)

# %% [markdown]
# # Evaluation

# %%
# The root mean squared error
RMSE = np.sqrt(mean_squared_error(y_te, pred))
RMSE
# Out:
# 15.790000750486108

# %%
# The mean absolute error
mae = mean_absolute_error(y_te, pred)
mae
# Out:
# 4.674018363748015

# %%
# The r2- score
r2= r2_score(y_te, pred)
r2
# Out:
# 0.9027005210703778

# %% [markdown]
# ## Cross-validation to prevent overfitting
#
# In this section, we performed the cross validation technique just to make sure our model is not overfitted.

# %%
# Defining our scoring metrics
scoring = {'r2': 'r2', 'mse': 'neg_mean_squared_error', 'mae': 'neg_mean_absolute_error'}

# Performing the cross validation
results = cross_validate(pipeline, X_tr, y_tr, scoring=scoring, cv=folds)

# Extracting the results for each metric
r2_scores = results['test_r2']
mse_scores = -results['test_mse']  
mae_scores = -results['test_mae']

# %%
r2_scores
# Out:
# array([0.87105191, 0.77992558, 0.92348493, 0.83319508, 0.84071177])

# %%
rmse_scores = np.sqrt(mse_scores)
rmse_scores
# Out:
# array([19.38448851, 23.23301067, 16.28696829, 24.63746873, 25.35390187])

# %%
mae_scores
# Out:
# array([4.73625238, 4.90106467, 4.75524842, 4.99687063, 5.25249347])
